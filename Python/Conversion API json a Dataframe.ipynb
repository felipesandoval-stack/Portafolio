# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from datetime import datetime
import os
import glob
from google.colab import files

# %%
AM = pd.read_excel('Archivo Maestro Programas.xlsx')
AM.head()
# Out:
#   Gp Acad                        Grupo Académico Grado Acad Base Nivel Acad  \
# 0   CECON  Ciencias Económicas y Administrativas            PREG    Carrera
# 1   CECON  Ciencias Económicas y Administrativas            PREG    Carrera
# 2   CECON  Ciencias Económicas y Administrativas            PREG    Carrera
# 3   CECON  Ciencias Económicas y Administrativas            PREG    Carrera
# 4   CECON  Ciencias Económicas y Administrativas            RAIP    Carrera
#
#   Prog. Acad.Base                 Descr Larga
# 0            ADMD  Administración De Empresas
# 1            ADMN  Administración De Empresas
# 2           ADMNN  Administración De Empresas
# 3           ADMND  Administración De Empresas
# 4              CN  Administración De Empresas

# %%
new_df =  pd.DataFrame(columns=['semestre','nombre_programa','nombre_facultad','grado','variable','cantidad'])

# %%
with open("/content/drive/My Drive/AC/AC/1210/LLMOD.json") as f:
    d = json.load(f)
    f = data[0]['Prog Acad']
    print(d)
# Out:
# [{'Prog Acad': 'LLMOD', 'Estado': 'AC', 'Tipo Admisión': 'IPS', 'desc_tipo_adm': 'Ingreso primer semestre', 'Q': 66}, {'Prog Acad': 'LLMOD', 'Estado': 'AC', 'Tipo Admisión': 'MLP', 'desc_tipo_adm': 'Multiple Programa', 'Q': 11}, {'Prog Acad': 'LLMOD', 'Estado': 'AC', 'Tipo Admisión': 'TFN', 'desc_tipo_adm': 'Transferencia', 'Q': 3}]

# %%
# lectura por carpeta v2 lectura multiples carpetas

path_to_json = '/content/drive/My Drive/AC/AC/1210'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

#creacion DF
jsons_data = pd.DataFrame(columns=['Gp Acad','Semestre'])
# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        try:
            Prog_Acad = json_text[0]['Prog Acad']
            semestre = json_text[0]['Q']
        except:
            pass
            # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [Prog_Acad,semestre]

jsons_data.head()
pre_ex = pd.merge(jsons_data, AM, on=["Gp Acad"])
pre_ex = pre_ex.loc[pre_ex['Grado Acad Base'] == 'GRAD'] #como se menciona en el documento mse filtra ACAD Carrer = GRAD
pre_ex['Variable'] = 'Inscritos'
pre_ex['Semestre'] = '1210'
pre_ex_1210 = pre_ex [['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']]

# %%
# lectura por carpeta v2 lectura multiples carpetas

path_to_json = '/content/drive/My Drive/AC/AC/1230'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

#creacion DF
jsons_data = pd.DataFrame(columns=['Gp Acad','Semestre'])
# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        try:
            Prog_Acad = json_text[0]['Prog Acad']
            semestre = json_text[0]['Q']
        except:
            pass
            # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [Prog_Acad,semestre]

jsons_data.head()
pre_ex = pd.merge(jsons_data, AM, on=["Gp Acad"])
pre_ex = pre_ex.loc[pre_ex['Grado Acad Base'] == 'GRAD'] #como se menciona en el documento mse filtra ACAD Carrer = GRAD
pre_ex['Variable'] = 'Inscritos'
pre_ex['Semestre'] = '1230'
pre_ex_1230 = pre_ex [['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']]

# %%
unificado = pd.concat([pre_ex_1210,pre_ex_1230], ignore_index=True)

# %%
# lectura por carpeta v2 lectura multiples carpetas

path_to_json = '/content/drive/My Drive/AC/AC/1310'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

#creacion DF
jsons_data = pd.DataFrame(columns=['Gp Acad','Semestre'])
# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        try:
            Prog_Acad = json_text[0]['Prog Acad']
            semestre = json_text[0]['Q']
        except:
            pass
            # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [Prog_Acad,semestre]

jsons_data.head()
pre_ex = pd.merge(jsons_data, AM, on=["Gp Acad"])
pre_ex = pre_ex.loc[pre_ex['Grado Acad Base'] == 'GRAD'] #como se menciona en el documento mse filtra ACAD Carrer = GRAD
pre_ex['Variable'] = 'Inscritos'
pre_ex['Semestre'] = '1310'
pre_ex_1310 = pre_ex [['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']]
unificado = pd.concat([unificado,pre_ex_1310], ignore_index=True)

# %%
# lectura por carpeta v2 lectura multiples carpetas

path_to_json = '/content/drive/My Drive/AC/AC/1330'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

#creacion DF
jsons_data = pd.DataFrame(columns=['Gp Acad','Semestre'])
# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        try:
            Prog_Acad = json_text[0]['Prog Acad']
            semestre = json_text[0]['Q']
        except:
            pass
            # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [Prog_Acad,semestre]

jsons_data.head()
pre_ex = pd.merge(jsons_data, AM, on=["Gp Acad"])
pre_ex = pre_ex.loc[pre_ex['Grado Acad Base'] == 'GRAD'] #como se menciona en el documento mse filtra ACAD Carrer = GRAD
pre_ex['Variable'] = 'Inscritos'
pre_ex['Semestre'] = '1330'
pre_ex_1330 = pre_ex [['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']]
unificado = pd.concat([unificado,pre_ex_1330], ignore_index=True)

# %%
# lectura por carpeta v2 lectura multiples carpetas

path_to_json = '/content/drive/My Drive/AC/AC/1410'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

#creacion DF
jsons_data = pd.DataFrame(columns=['Gp Acad','Semestre'])
# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        try:
            Prog_Acad = json_text[0]['Prog Acad']
            semestre = json_text[0]['Q']
        except:
            pass
            # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [Prog_Acad,semestre]

jsons_data.head()
pre_ex = pd.merge(jsons_data, AM, on=["Gp Acad"])
pre_ex = pre_ex.loc[pre_ex['Grado Acad Base'] == 'GRAD'] #como se menciona en el documento mse filtra ACAD Carrer = GRAD
pre_ex['Variable'] = 'Inscritos'
pre_ex['Semestre'] = '1410'
pre_ex_1410= pre_ex [['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']]
unificado = pd.concat([unificado,pre_ex_1410], ignore_index=True)

# %%
# lectura por carpeta v2 lectura multiples carpetas

path_to_json = '/content/drive/My Drive/AC/AC/1430'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

#creacion DF
jsons_data = pd.DataFrame(columns=['Gp Acad','Semestre'])
# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        try:
            Prog_Acad = json_text[0]['Prog Acad']
            semestre = json_text[0]['Q']
        except:
            pass
            # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [Prog_Acad,semestre]

jsons_data.head()
pre_ex = pd.merge(jsons_data, AM, on=["Gp Acad"])
pre_ex = pre_ex.loc[pre_ex['Grado Acad Base'] == 'GRAD'] #como se menciona en el documento mse filtra ACAD Carrer = GRAD
pre_ex['Variable'] = 'Inscritos'
pre_ex['Semestre'] = '1430'
pre_ex_1430= pre_ex [['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']]
unificado = pd.concat([unificado,pre_ex_1430], ignore_index=True)

# %%
# lectura por carpeta v2 lectura multiples carpetas

path_to_json = '/content/drive/My Drive/AC/AC/1510'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

#creacion DF
jsons_data = pd.DataFrame(columns=['Gp Acad','Semestre'])
# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        try:
            Prog_Acad = json_text[0]['Prog Acad']
            semestre = json_text[0]['Q']
        except:
            pass
            # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [Prog_Acad,semestre]

jsons_data.head()
pre_ex = pd.merge(jsons_data, AM, on=["Gp Acad"])
pre_ex = pre_ex.loc[pre_ex['Grado Acad Base'] == 'GRAD'] #como se menciona en el documento mse filtra ACAD Carrer = GRAD
pre_ex['Variable'] = 'Inscritos'
pre_ex['Semestre'] = '1510'
pre_ex_1510= pre_ex [['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']]
unificado = pd.concat([unificado,pre_ex_1510], ignore_index=True)

# %%
# lectura por carpeta v2 lectura multiples carpetas

path_to_json = '/content/drive/My Drive/AC/AC/1530'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

#creacion DF
jsons_data = pd.DataFrame(columns=['Gp Acad','Semestre'])
# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        try:
            Prog_Acad = json_text[0]['Prog Acad']
            semestre = json_text[0]['Q']
        except:
            pass
            # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [Prog_Acad,semestre]

jsons_data.head()
pre_ex = pd.merge(jsons_data, AM, on=["Gp Acad"])
pre_ex = pre_ex.loc[pre_ex['Grado Acad Base'] == 'GRAD'] #como se menciona en el documento mse filtra ACAD Carrer = GRAD
pre_ex['Variable'] = 'Inscritos'
pre_ex['Semestre'] = '1530'
pre_ex_1530= pre_ex [['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']]
unificado = pd.concat([unificado,pre_ex_1530], ignore_index=True)

# %%
########################
########################
######################## NOTA: lo ideal seria haberlo hecho en una funcion y ponerla a iterar por las carpetas debido a la premura del tiempo se hace manual y secuencial

# %%
unificado = unificado.groupby(['Semestre','Descr Larga','Grupo Académico','Grado Acad Base','Variable']).size().reset_index(name='counts')
unificado.head()
# Out:
#   Semestre                                        Descr Larga Grupo Académico  \
# 0     1210                Doctorado Eclesiástico En Filosofía       Filosofía
# 1     1210                 Doctorado En Epidemiología Clínica        Medicina
# 2     1210                             Doctorado En Filosofía       Filosofía
# 3     1210                         Doctorado En Neurociencias        Medicina
# 4     1210  Especializacion En Medicina Del Dolor Y Cuidad...        Medicina
#
#   Grado Acad Base   Variable  counts
# 0            GRAD  Inscritos       1
# 1            GRAD  Inscritos       1
# 2            GRAD  Inscritos       1
# 3            GRAD  Inscritos       1
# 4            GRAD  Inscritos       2

# %%
unificado.to_excel('unificado.xlsx', index=False)
